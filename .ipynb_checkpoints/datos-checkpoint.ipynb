# %%
import pandas as pd
import webbrowser
import pyautogui
import time


df = pd.read_excel('datosdtech.xlsx')

part_number = df.loc[0, 'Part Number']

search_url = f"https://www.google.com//?q={part_number}"  

webbrowser.open(search_url)

time.sleep(3)

pyautogui.press('enter')

# %%
import pandas as pd

df = pd.read_excel('datosdtech.xlsx')

df
# Out:
#                      Item No.       Part Number  \
# 0         3RB-APP-MV7N2AM/A-W         MV7N2AM/A
# 1       3RB-HPP-5T9T7UA#ABA-P       5T9T7UA#ABA
# 2      3RB-HPP-6L6B7UAR#ABA-S      6L6B7UAR#ABA
# 3      3RB-HPP-81K12UAR#ABA-B      81K12UAR#ABA
# 4    3RB-HPP-HP830G7.I7.10.-S    HP830G7.I7.10.
# ..                        ...               ...
# 993              WDA-WEB1080P          WEB1080P
# 994    WES-WDBU6Y0040BBK-WE-B  WDBU6Y0040BBK-WE
# 995           WIN-WXMPB130N-B         WXMPB130N
# 996           WIN-WXMPB130P-P         WXMPB130P
# 997           XIA-BHR6540GL-W         BHR6540GL
#
#                                       Item Description  \
# 0    APPLE AIRPODS 2ND GEN CHARGING CASE STEREO WIR...
# 1    HP 14-CF2112WM, 14"HD, CELERON N4020, 4GB, 64G...
# 2    HP 15-DY0700TG, 15.6"HD, PENTIUM SILVER N5030 ...
# 3    HP 14-FQ1003CL , 14"HD TOUCH, RYZEN 3 5300U, 8...
# 4    HP  ELITEBOOK 830 G7 I7-10 32GB RAM 512GB SSD ...
# ...
